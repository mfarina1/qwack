# %%
def level_select():
    duck_button = pygame.Rect(0,0,64,64)
    running = True
    while running:
        
        #Initialize
        screen.fill((0,0,0))
        screen.blit(bg, (0,0))
        mx, my = pygame.mouse.get_pos()
        
#         #icon bouncing in background
#         if iconX >= 800-duck_button.width:
#             velocity[0] = -velocity[0]
#         if iconX <= 0:
#             velocity[0] = -velocity[0]
#         if iconY > 600-duck_button.height:
#             velocity[1] = -velocity[1]
#         if iconY < 0:
#             velocity[1] = -velocity[1] 
            
            
#         iconX += velocity[0]
#         iconY += velocity[1]
#         if isAlive:
#             duck_button = Icon(icon, iconX, iconY)
        
        home_button = draw_text("Qwack", fontTitle, themeColor, screen, 262, 15)
        draw_text("Level Select", fontSubHeader, (255, 255, 255), screen, 307, 110)
        draw_text("___________", fontSubHeader, (255, 255, 255), screen, 307.25, 112)
        esc_button = draw_text("Press Esc To Return", text, themeColor, screen, 10, 15)
        buttonLevel_0 = draw_text("Level 0: Tutorial", text, (255, 255, 255), screen, 75, 175)
        buttonLevel_1 = draw_text("Level 1: Build a Circuit", text, (255, 255, 255), screen, 75, 225)
        buttonLevel_2 = draw_text("Level 2: Superposition", text, (255, 255, 255), screen, 75, 275)
        buttonLevel_3 = draw_text("Level 3: Entanglement", text, (255, 255, 255), screen, 75, 325)
        buttonLevel_4 = draw_text("Level 4: Teleportation", text, (255, 255, 255), screen, 75, 375)

        
        #player
        playerX = 370
        playerY = 490
        xChange = 0
        yChange = 0
        
        
            
        click = False
        for event in pygame.event.get():
            if event.type == QUIT:
                pygame.quit()
                sys.exit()
            if event.type == KEYDOWN:
                if event.key == K_ESCAPE:
                    running = False
            if event.type == MOUSEBUTTONDOWN:
                if event.button == 1:
                    click = True
                    
        if home_button.collidepoint((mx, my)) or esc_button.collidepoint((mx, my)):
            if click:
                main_menu(iconX, iconY, isAlive) 
        if buttonLevel_0.collidepoint((mx, my)):
            if click:
                level_0(playerX, playerY, xChange, yChange)
        if buttonLevel_1.collidepoint((mx, my)):
            if click:
                level_1(playerX, playerY, xChange, yChange)
        if buttonLevel_2.collidepoint((mx, my)):
            if click:
                level2()
        if buttonLevel_3.collidepoint((mx, my)):
            if click:
                entanglement()
        if buttonLevel_4.collidepoint((mx, my)):
            if click:
                classical_teleportation()
        pygame.display.update()
        mainClock.tick(120)
