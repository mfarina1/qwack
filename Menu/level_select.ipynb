# %%
def level_select():
    color0 = (255,255,255)
    color1 = (255,255,255)
    color2 = (255,255,255)
    color3 = (255,255,255)
    color4 = (255,255,255)
    duck_button = pygame.Rect(0,0,64,64)
    running = True
    BLACK = [0,0,0]
    WHITE = [255,255,255]
    while running:
        
        #Initialize
        screen.fill((0,0,0))
        screen.blit(bg, (0,0))
        mx, my = pygame.mouse.get_pos()

        buttonLevel_0 = pygame.Rect(0,0,210, 30)
        buttonLevel_0.center = (168, 184)
        
        
        buttonLevel_1 = pygame.Rect(0,0,210, 30)
        buttonLevel_1.center = (168, 233)
        
        
        buttonLevel_2 = pygame.Rect(0,0,210, 30)
        buttonLevel_2.center = (168, 284)
        
        buttonLevel_3 = pygame.Rect(0,0,210, 30)
        buttonLevel_3.center = (168, 333)
        
        
        buttonLevel_4 = pygame.Rect(0,0,210, 30)
        buttonLevel_4.center = (168, 384)
        
        
        if buttonLevel_0.collidepoint(pygame.mouse.get_pos()):
            pygame.draw.rect(screen, themeColor, buttonLevel_0)
            color0List = list(color0)
            color0List = BLACK
            color0 = tuple(color0List)
        else:
            color0List = list(color0)
            color0List = WHITE
            color0 = tuple(color0List)
        if buttonLevel_1.collidepoint(pygame.mouse.get_pos()):
            pygame.draw.rect(screen, themeColor, buttonLevel_1)
            color1List = list(color1)
            color1List = BLACK
            color1 = tuple(color1List)
        else: 
            color1List = list(color1)
            color1List = WHITE
            color1 = tuple(color1List)
        if buttonLevel_2.collidepoint(pygame.mouse.get_pos()):
            pygame.draw.rect(screen, themeColor, buttonLevel_2)
            color2List = list(color2)
            color2List = BLACK
            color2 = tuple(color2List)
        else:
            color2List = list(color2)
            color2List = WHITE
            color2 = tuple(color2List)
        if buttonLevel_3.collidepoint(pygame.mouse.get_pos()):
            pygame.draw.rect(screen, themeColor, buttonLevel_3)
            color3List = list(color3)
            color3List = BLACK
            color3 = tuple(color3List)
        else:
            color3List = list(color3)
            color3List = WHITE
            color3 = tuple(color3List)
        if buttonLevel_4.collidepoint(pygame.mouse.get_pos()):
            pygame.draw.rect(screen, themeColor, buttonLevel_4)
            color4List = list(color4)
            color4List = BLACK
            color4 = tuple(color4List)
        else:
            color4List = list(color4)
            color4List = WHITE
            color4 = tuple(color4List)
        
        home_button = draw_text("Qwack", fontTitle, themeColor, screen, 285, 15)
        draw_text("Level Select", fontSubHeader, (255, 255, 255), screen, 307, 110)
        draw_text("___________", fontSubHeader, (255, 255, 255), screen, 307.25, 112)
        esc_button = draw_text("Press Esc To Return", text, themeColor, screen, 10, 15)
        draw_text("Level 0: Tutorial", text, color0, screen, 75, 175)
        draw_text("Level 1: Build a Circuit", text, color1, screen, 75, 225)
        draw_text("Level 2: Superposition", text, color2, screen, 75, 275)
        draw_text("Level 3: Entanglement", text, color3, screen, 75, 325)
        draw_text("Level 4: Teleportation", text, color4, screen, 75, 375)

        
        #player
        playerX = 370
        playerY = 490
        xChange = 0
        yChange = 0
        
        
            
        click = False
        for event in pygame.event.get():
            if event.type == QUIT:
                pygame.quit()
                sys.exit()
            if event.type == KEYDOWN:
                if event.key == K_ESCAPE:
                    running = False
            if event.type == MOUSEBUTTONDOWN:
                if event.button == 1:
                    click = True
                    print(pygame.mouse.get_pos())
                    
        if home_button.collidepoint((mx, my)) or esc_button.collidepoint((mx, my)):
            if click:
                main_menu(iconX, iconY, isAlive) 
        if buttonLevel_0.collidepoint((mx, my)):
            if click:
                level_0(playerX, playerY, xChange, yChange)
        if buttonLevel_1.collidepoint((mx, my)):
            if click:
                level_1(playerX, playerY, xChange, yChange)
        if buttonLevel_2.collidepoint((mx, my)):
            if click:
                level2()
        if buttonLevel_3.collidepoint((mx, my)):
            if click:
                entanglement()
        if buttonLevel_4.collidepoint((mx, my)):
            if click:
                classical_teleportation()
        pygame.display.update()
        mainClock.tick(120)
# Out:
#   File "<ipython-input-1-b67ac0799332>", line 63
#     home_button = draw_text("Qwack", fontTitle, themeColor, screen, 262, 15)
#     ^
# IndentationError: expected an indented block
